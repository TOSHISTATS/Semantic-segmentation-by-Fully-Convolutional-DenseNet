# %% [markdown]
# #  Semantic segmentation by Fully Convolutional DenseNet56 with Keras2.0

# %% [markdown]
# ###  This is my experiment to see how Fully Convolutional DenseNet56 works with little data

# %% [markdown]
# For theory and algorithm. please refer to "The One Hundred Layers Tiramisu: Fully Convolutional DenseNets for Semantic Segmentation (Simon Jegou, Michal Drozdzal, David Vazquez, Adriana Romero, Yoshua Bengio),  5 Dec 2016"
# https://arxiv.org/abs/1611.09326
#
# Origingal code in fast.ai by Jeremy Howard is provided with this link. I rewrite it with keras2 and modify https://github.com/fastai/courses/blob/master/deeplearning2/tiramisu-keras.ipynb
#
# For data, http://mi.eng.cam.ac.uk/research/projects/VideoRec/CamVid/
# Segmentation and Recognition Using Structure from Motion Point Clouds, ECCV 2008 Brostow, Shotton, Fauqueur, Cipolla

# %%
import os
import h5py
import numpy as np
import tensorflow as tf
import time
import glob
import json
import csv
import bcolz
import threading
import random
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

import keras
from keras import applications
from keras.preprocessing import image

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D,Cropping2D,BatchNormalization,Conv2DTranspose
from keras.layers import Activation, Dropout, Flatten, Dense, Lambda, GlobalAveragePooling2D, Reshape
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential

from keras.engine import Input
from keras.layers.merge import concatenate
from keras.layers.pooling import AveragePooling2D
from keras.regularizers import l2
from keras.utils import np_utils
from keras.optimizers import SGD

sess = tf.Session()
from keras import backend as K
K.set_session(sess)

# %% [markdown]
# ## 1. Data preparation

# %% [markdown]
# CamVid., sciene-images data set, is used.

# %%
PATH='/data/camvid/'

# %% [markdown]
# ### 1.1  Read name of images

# %%
frames_path = PATH+'701_StillsRaw_full/'

# %%
labels_path = PATH+'LabeledApproved_full/'

# %%
fnames = glob.glob(frames_path+'*.png')

# %%
lnames = [labels_path+os.path.basename(fn)[:-4]+'_L.png' for fn in fnames]

# %%
img_sz = (480,360)

# %%
def open_image(fn): return np.array(Image.open(fn).resize(img_sz, Image.NEAREST))

# %%
img = Image.open(fnames[0]).resize(img_sz, Image.NEAREST)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=480x360 at 0x11C03A550>

# %% [markdown]
# ### 1.2 Load images

# %%
imgs = np.stack([open_image(fn) for fn in fnames])

# %%
labels = np.stack([open_image(fn) for fn in lnames])

# %%
imgs.shape,labels.shape
# Out:
# ((701, 360, 480, 3), (701, 360, 480, 3))

# %% [markdown]
# ### 1.3 Save array

# %%
def save_array(fname, arr):
    c=bcolz.carray(arr, rootdir=fname, mode='w')
    c.flush()

def load_array(fname): return bcolz.open(fname)[:]

# %%
#Normalize pixel values
imgs=imgs/255.

# %%
save_array(PATH+'results/imgs.bc', imgs)
save_array(PATH+'results/labels.bc', labels)

# %%
imgs = load_array(PATH+'results/imgs.bc')
labels = load_array(PATH+'results/labels.bc')

# %% [markdown]
# ### 1.4 Standardize values of image data

# %%
av=np.mean(imgs)
sd=np.std(imgs)
av,sd
# Out:
# (0.39996644266360826, 0.3017949114229091)

# %%
imgs-=av
imgs/=sd

# %%
n,r,c,ch = imgs.shape

# %% [markdown]
# ## 2.Data Preprocessing

# %% [markdown]
# ### 2.1 Data generator

# %% [markdown]
# This implementation employs data augmentation on CamVid.
#
# Augmentation includes random cropping / horizontal flipping, as done by `segm_generator()`. `BatchIndices()` lets us randomly sample batches from input array.

# %%
class BatchIndices(object):
    def __init__(self, n, bs, shuffle=False):
        self.n,self.bs,self.shuffle = n,bs,shuffle
        self.lock = threading.Lock()
        self.reset()

    def reset(self):
        self.idxs = (np.random.permutation(self.n) 
                     if self.shuffle else np.arange(0, self.n))
        self.curr = 0

    def __next__(self):
        with self.lock:
            if self.curr >= self.n: self.reset()
            ni = min(self.bs, self.n-self.curr)
            res = self.idxs[self.curr:self.curr+ni]
            self.curr += ni
            return res

# %%
bi = BatchIndices(10,3)
[next(bi) for o in range(5)]
# Out:
# [array([0, 1, 2]),
#  array([3, 4, 5]),
#  array([6, 7, 8]),
#  array([9]),
#  array([0, 1, 2])]

# %%
bi = BatchIndices(10,3,True)
[next(bi) for o in range(5)]
# Out:
# [array([7, 2, 6]),
#  array([9, 4, 1]),
#  array([0, 8, 5]),
#  array([3]),
#  array([9, 3, 6])]

# %%
class segm_generator(object):
    def __init__(self, x, y, bs=64, out_sz=(224,224), train=True):
        self.x, self.y, self.bs, self.train = x,y,bs,train
        self.n, self.ri, self.ci, _ = x.shape
        self.idx_gen = BatchIndices(self.n, bs, train)
        self.ro, self.co = out_sz
        self.ych = self.y.shape[-1] if len(y.shape)==4 else 1

    def get_slice(self, i,o):
        start = random.randint(0, i-o) if self.train else (i-o)
        return slice(start, start+o)

    def get_item(self, idx):
        slice_r = self.get_slice(self.ri, self.ro)
        slice_c = self.get_slice(self.ci, self.co)
        x = self.x[idx, slice_r, slice_c]
        y = self.y[idx, slice_r, slice_c]
        if self.train and (random.random()>0.5): 
            y = y[:,::-1]
            x = x[:,::-1]
        return x, y

    def __next__(self):
        idxs = next(self.idx_gen)
        items = (self.get_item(idx) for idx in idxs)
        xs,ys = zip(*items)
        return np.stack(xs), np.stack(ys).reshape(len(ys), -1, self.ych)

# %% [markdown]
# As an example, here's a crop of the image.

# %%
sg = segm_generator(imgs, labels, 4, train=False)
b_img, b_label = next(sg)
plt.imshow(b_img[0]*0.3+0.4);

# %%
plt.imshow(imgs[0]*0.3+0.4);

# %%
sg = segm_generator(imgs, labels, 4, train=True)
b_img, b_label = next(sg)
plt.imshow(b_img[0]*0.3+0.4);

# %% [markdown]
# ### 2.2 Convert labels

# %% [markdown]
# The following loads, parses, and converts the segment labels we need for targets.
#
# In particular we're looking to make the segmented targets into integers for classification purposes.

# %% [markdown]
# Each segment / category is indicated by a particular color. The following maps each unique pixel to it's category.

# %%
for l in open(PATH+"label_colors.txt"):
    aa = l[:-1].split("\t")
    a=aa[0]
    b=aa[1]
    print(aa)
# Out:
# ['64 128 64', 'Animal']
# ['192 0 128', 'Archway']
# ['0 128 192', 'Bicyclist']
# ['0 128 64', 'Bridge']
# ['128 0 0', 'Building']
# ['64 0 128', 'Car']
# ['64 0 192', 'CartLuggagePram']
# ['192 128 64', 'Child']
# ['192 192 128', 'Column_Pole']
# ['64 64 128', 'Fence']
# ['128 0 192', 'LaneMkgsDriv']
# ['192 0 64', 'LaneMkgsNonDriv']
# ['128 128 64', 'Misc_Text']
# ['192 0 192', 'MotorcycleScooter']
# ['128 64 64', 'OtherMoving']
# ['64 192 128', 'ParkingBlock']
# ['64 64 0', 'Pedestrian']
# ['128 64 128', 'Road']
# ['128 128 192', 'RoadShoulder']
# ['0 0 192', 'Sidewalk']
# ['192 128 128', 'SignSymbol']
# ['128 128 128', 'Sky']
# ['64 128 192', 'SUVPickupTruck']
# ['0 0 64', 'TrafficCone']
# ['0 64 64', 'TrafficLight']
# ['192 64 128', 'Train']
# ['128 128 0', 'Tree']
# ['192 128 192', 'Truck_Bus']
# ['64 0 64', 'Tunnel']
# ['192 192 0', 'VegetationMisc']
# ['0 0 0', 'Void']
# ['64 192 0', 'Wall']

# %%
def parse_code(l):
    a,b = l.strip().split("\t")
    return tuple(int(o) for o in a.split(' ')), b

# %%
label_codes,label_names = zip(*[parse_code(l) for l in open(PATH+"label_colors.txt")])

# %%
label_codes,label_names = list(label_codes),list(label_names)

# %%
list(zip(label_codes,label_names))[:5]
# Out:
# [((64, 128, 64), 'Animal'),
#  ((192, 0, 128), 'Archway'),
#  ((0, 128, 192), 'Bicyclist'),
#  ((0, 128, 64), 'Bridge'),
#  ((128, 0, 0), 'Building')]

# %% [markdown]
# We're going to map each unique pixel color to an integer so we can classify w/ our NN

# %%
code2id = {v:k for k,v in enumerate(label_codes)}

# %% [markdown]
# We'll include an integer for erroneous pixel values.

# %%
failed_code = len(label_codes)+1

# %%
label_codes.append((0,0,0))
label_names.append('unk')

# %%
def conv_one_label(i): 
    res = np.zeros((r,c), 'uint8')
    for j in range(r): 
        for k in range(c):
            try: res[j,k] = code2id[tuple(labels[i,j,k])]
            except: res[j,k] = failed_code
    return res

# %%
from concurrent.futures import ProcessPoolExecutor

# %%
def conv_all_labels():
    ex = ProcessPoolExecutor(8)
    return np.stack(ex.map(conv_one_label, range(n)))

# %% [markdown]
# Now we'll create integer-mapped labels for all our colored images.

# %%
# %time labels_int =conv_all_labels()
# Out:
# CPU times: user 1.01 s, sys: 1.63 s, total: 2.64 s
# Wall time: 18min 18s

# %%
np.count_nonzero(labels_int==failed_code)
# Out:
# 44

# %% [markdown]
# Set erroneous pixels to zero.

# %%
labels_int.shape
# Out:
# (701, 360, 480)

# %%
labels_int[labels_int==failed_code]=0

# %%
save_array(PATH+'results/labels_int.bc', labels_int)

# %%
labels_int = load_array(PATH+'results/labels_int.bc')

# %%
sg = segm_generator(imgs, labels, 4, train=True)
b_img, b_label = next(sg)
plt.imshow(b_img[0]*0.3+0.4);

# %% [markdown]
# Here is an example of how the segmented image looks.

# %%
plt.imshow(b_label[0].reshape(224,224,3));

# %% [markdown]
# ### 2.3 Split training set and test set

# %% [markdown]
# Next we load test set, set training/test images and labels.

# %%
trn = imgs[0:468]
trn_labels = labels_int[0:468]
test = imgs[468:701]
test_labels = labels_int[468:701]
trn.shape, trn_labels.shape, test.shape, test_labels.shape
# Out:
# ((468, 360, 480, 3), (468, 360, 480), (233, 360, 480, 3), (233, 360, 480))

# %%
rnd_trn = len(trn_labels)
rnd_test = len(test_labels)

# %% [markdown]
# ## 3. Build "Fully Convolutional DenseNet56 "

# %% [markdown]
# ### 3.1 Helper functions

# %%
def relu(x): return Activation('relu')(x)
def dropout(x, p): return Dropout(p)(x) if p else x
def bn(x): return BatchNormalization( axis=-1)(x)
def relu_bn(x): return relu(bn(x))
def concat(xs): return concatenate(xs, axis=-1)

# %%
def conv(x, nf, sz, wd, p, stride=1): 
    x = Conv2D(nf, sz, kernel_initializer='he_uniform', padding='same', 
                      strides=(stride,stride), kernel_regularizer=l2(wd))(x)
    return dropout(x, p)

def conv_relu_bn(x, nf, sz=3, wd=0, p=0, stride=1): 
    return conv(relu_bn(x), nf, sz, wd=wd, p=p, stride=stride)

# %% [markdown]
# Recall the dense block from DenseNet.

# %%
def dense_block(n,x,growth_rate,p,wd):
    added = []
    for i in range(n):
        b = conv_relu_bn(x, growth_rate, p=p, wd=wd)
        x = concat([x, b])
        added.append(b)
    return x,added

# %% [markdown]
# This is the downsampling transition.
#
# In the original paper, downsampling consists of 1x1 convolution followed by max pooling. However we've found a stride 2 1x1 convolution to give better results.

# %%
def transition_dn(x, p, wd):
#     x = conv_relu_bn(x, x.get_shape().as_list()[-1], sz=1, p=p, wd=wd)
#     return MaxPooling2D(strides=(2, 2))(x)
    return conv_relu_bn(x, x.get_shape().as_list()[-1], sz=1, p=p, wd=wd, stride=2)

# %% [markdown]
# Next we build the entire downward path, keeping track of Dense block outputs in a list called `skip`.

# %%
def down_path(x, nb_layers, growth_rate, p, wd):
    skips = []
    for i,n in enumerate(nb_layers):
        x,added = dense_block(n,x,growth_rate,p,wd)
        skips.append(x)
        x = transition_dn(x, p=p, wd=wd)
    return skips, added

# %% [markdown]
# This is the upsampling transition. We use a transpose convolution layer.

# %%
def transition_up(added, wd=0):
    x = concat(added)
    _,r,c,ch = x.get_shape().as_list()
    return Conv2DTranspose(ch, 3,  kernel_initializer='he_uniform', 
               padding='same', strides=(2,2), kernel_regularizer=l2(wd))(x)
#     x = UpSampling2D()(x)
#     return conv(x, ch, 2, wd, 0)

# %% [markdown]
# This builds our upward path, concatenating the skip connections from `skip` to the Dense block inputs.

# %%
def up_path(added, skips, nb_layers, growth_rate, p, wd):
    for i,n in enumerate(nb_layers):
        x = transition_up(added, wd)
        x = concat([x,skips[i]])
        x,added = dense_block(n,x,growth_rate,p,wd)
    return x

# %% [markdown]
# ### 3.2 Build the model

# %% [markdown]
# - nb_classes: number of classes
# - img_input: tuple of shape (channels, rows, columns) or (rows, columns, channels)
# - nb_dense_block: number of dense blocks to add
# - growth_rate: number of filters to add per dense block
# - nb_filter:  initial number of filters
# - nb_layers_per_block: number of layers in each dense block.
#   - If positive integer, a set number of layers per dense block.
#   - If list, nb_layer is used as provided
# - p: dropout rate
# - wd: weight decay

# %%
def reverse(a): return list(reversed(a))

# %% [markdown]
# Finally we put together the entire network.

# %%
def create_tiramisu(nb_classes, img_input, nb_dense_block=6, 
    growth_rate=12, nb_filter=48, nb_layers_per_block=4, p=None, wd=0):
    
    if type(nb_layers_per_block) is list or type(nb_layers_per_block) is tuple:
        nb_layers = list(nb_layers_per_block)
    else: nb_layers = [nb_layers_per_block] * nb_dense_block

    x = conv(img_input, nb_filter, 3, wd, 0)
    skips,added = down_path(x, nb_layers, growth_rate, p, wd)
    x = up_path(added, reverse(skips[:-1]), reverse(nb_layers[:-1]), growth_rate, p, wd)
    
    x = conv(x, nb_classes, 1, wd, 0)
    _,r,c,f = x.get_shape().as_list()
    x = Reshape((-1, nb_classes))(x)
    return Activation('softmax')(x)

# %% [markdown]
# ## 4. Train the model

# %% [markdown]
# ### 4.1 Training on argumented images

# %%
input_shape = (224,224,3)

# %%
img_input = Input(shape=input_shape)

# %%
from keras.layers import

# %%
x = create_tiramisu(33, img_input, nb_layers_per_block=4, p=0.2, wd=1e-4)

# %%
model = Model(img_input, x)

# %%
gen = segm_generator(trn, trn_labels, 3, train=True)

# %%
gen_test = segm_generator(test, test_labels, 3, train=False)

# %%
model.compile(loss='sparse_categorical_crossentropy',  optimizer=keras.optimizers.RMSprop(1e-3), metrics=["accuracy"])

filepath='tiramisu.{epoch:02d}-{val_acc:.2f}.hdf5'
mc_cb = keras.callbacks.ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='max')

# %%
model.optimizer=keras.optimizers.RMSprop(1e-3, decay=1-0.99995)

# %% [markdown]
# To obtain accuracy over 85%,  it may take more than 24-48 hours (50-100 epochs) when you use Mac air (without GPU)
# Please look at http://www.toshistats.net/deep-learning-blog/2017/8/12/this-is-incredible-semantic-segmentation-by-just-700-images-from-scratch-with-mac-air

# %%
batch_size=10
epochs=2

import time
t=time.time()  

history=model.fit_generator(gen, rnd_trn//batch_size,  epochs, verbose=2,
                    validation_data=gen_test, validation_steps=rnd_test//batch_size, callbacks=[mc_cb])

t2 = time.time()
print(round(t2-t, 5), 'Seconds to predict')

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['loss', 'val_loss'], loc='upper right')
plt.show()

model.summary()
# Out:
# Epoch 1/2
# Epoch 00000: val_acc improved from -inf to 0.03161, saving model to tiramisu.00-0.03.hdf5
# 2234s - loss: 2.6416 - acc: 0.4441 - val_loss: 7.6740 - val_acc: 0.0316
# Epoch 2/2
# Epoch 00001: val_acc improved from 0.03161 to 0.58225, saving model to tiramisu.01-0.58.hdf5
# 2105s - loss: 2.0922 - acc: 0.4787 - val_loss: 1.6091 - val_acc: 0.5823
# 4385.89806 Seconds to predict
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# conv2d_84 (Conv2D)               (None, 224, 224, 48)  1344        input_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_81 (BatchNor (None, 224, 224, 48)  192         conv2d_84[0][0]
# ____________________________________________________________________________________________________
# activation_81 (Activation)       (None, 224, 224, 48)  0           batch_normalization_81[0][0]
# ____________________________________________________________________________________________________
# conv2d_85 (Conv2D)               (None, 224, 224, 12)  5196        activation_81[0][0]
# ____________________________________________________________________________________________________
# dropout_81 (Dropout)             (None, 224, 224, 12)  0           conv2d_85[0][0]
# ____________________________________________________________________________________________________
# concatenate_80 (Concatenate)     (None, 224, 224, 60)  0           conv2d_84[0][0]
#                                                                    dropout_81[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_82 (BatchNor (None, 224, 224, 60)  240         concatenate_80[0][0]
# ____________________________________________________________________________________________________
# activation_82 (Activation)       (None, 224, 224, 60)  0           batch_normalization_82[0][0]
# ____________________________________________________________________________________________________
# conv2d_86 (Conv2D)               (None, 224, 224, 12)  6492        activation_82[0][0]
# ____________________________________________________________________________________________________
# dropout_82 (Dropout)             (None, 224, 224, 12)  0           conv2d_86[0][0]
# ____________________________________________________________________________________________________
# concatenate_81 (Concatenate)     (None, 224, 224, 72)  0           concatenate_80[0][0]
#                                                                    dropout_82[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_83 (BatchNor (None, 224, 224, 72)  288         concatenate_81[0][0]
# ____________________________________________________________________________________________________
# activation_83 (Activation)       (None, 224, 224, 72)  0           batch_normalization_83[0][0]
# ____________________________________________________________________________________________________
# conv2d_87 (Conv2D)               (None, 224, 224, 12)  7788        activation_83[0][0]
# ____________________________________________________________________________________________________
# dropout_83 (Dropout)             (None, 224, 224, 12)  0           conv2d_87[0][0]
# ____________________________________________________________________________________________________
# concatenate_82 (Concatenate)     (None, 224, 224, 84)  0           concatenate_81[0][0]
#                                                                    dropout_83[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_84 (BatchNor (None, 224, 224, 84)  336         concatenate_82[0][0]
# ____________________________________________________________________________________________________
# activation_84 (Activation)       (None, 224, 224, 84)  0           batch_normalization_84[0][0]
# ____________________________________________________________________________________________________
# conv2d_88 (Conv2D)               (None, 224, 224, 12)  9084        activation_84[0][0]
# ____________________________________________________________________________________________________
# dropout_84 (Dropout)             (None, 224, 224, 12)  0           conv2d_88[0][0]
# ____________________________________________________________________________________________________
# concatenate_83 (Concatenate)     (None, 224, 224, 96)  0           concatenate_82[0][0]
#                                                                    dropout_84[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_85 (BatchNor (None, 224, 224, 96)  384         concatenate_83[0][0]
# ____________________________________________________________________________________________________
# activation_85 (Activation)       (None, 224, 224, 96)  0           batch_normalization_85[0][0]
# ____________________________________________________________________________________________________
# conv2d_89 (Conv2D)               (None, 112, 112, 96)  9312        activation_85[0][0]
# ____________________________________________________________________________________________________
# dropout_85 (Dropout)             (None, 112, 112, 96)  0           conv2d_89[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_86 (BatchNor (None, 112, 112, 96)  384         dropout_85[0][0]
# ____________________________________________________________________________________________________
# activation_86 (Activation)       (None, 112, 112, 96)  0           batch_normalization_86[0][0]
# ____________________________________________________________________________________________________
# conv2d_90 (Conv2D)               (None, 112, 112, 12)  10380       activation_86[0][0]
# ____________________________________________________________________________________________________
# dropout_86 (Dropout)             (None, 112, 112, 12)  0           conv2d_90[0][0]
# ____________________________________________________________________________________________________
# concatenate_84 (Concatenate)     (None, 112, 112, 108) 0           dropout_85[0][0]
#                                                                    dropout_86[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_87 (BatchNor (None, 112, 112, 108) 432         concatenate_84[0][0]
# ____________________________________________________________________________________________________
# activation_87 (Activation)       (None, 112, 112, 108) 0           batch_normalization_87[0][0]
# ____________________________________________________________________________________________________
# conv2d_91 (Conv2D)               (None, 112, 112, 12)  11676       activation_87[0][0]
# ____________________________________________________________________________________________________
# dropout_87 (Dropout)             (None, 112, 112, 12)  0           conv2d_91[0][0]
# ____________________________________________________________________________________________________
# concatenate_85 (Concatenate)     (None, 112, 112, 120) 0           concatenate_84[0][0]
#                                                                    dropout_87[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_88 (BatchNor (None, 112, 112, 120) 480         concatenate_85[0][0]
# ____________________________________________________________________________________________________
# activation_88 (Activation)       (None, 112, 112, 120) 0           batch_normalization_88[0][0]
# ____________________________________________________________________________________________________
# conv2d_92 (Conv2D)               (None, 112, 112, 12)  12972       activation_88[0][0]
# ____________________________________________________________________________________________________
# dropout_88 (Dropout)             (None, 112, 112, 12)  0           conv2d_92[0][0]
# ____________________________________________________________________________________________________
# concatenate_86 (Concatenate)     (None, 112, 112, 132) 0           concatenate_85[0][0]
#                                                                    dropout_88[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_89 (BatchNor (None, 112, 112, 132) 528         concatenate_86[0][0]
# ____________________________________________________________________________________________________
# activation_89 (Activation)       (None, 112, 112, 132) 0           batch_normalization_89[0][0]
# ____________________________________________________________________________________________________
# conv2d_93 (Conv2D)               (None, 112, 112, 12)  14268       activation_89[0][0]
# ____________________________________________________________________________________________________
# dropout_89 (Dropout)             (None, 112, 112, 12)  0           conv2d_93[0][0]
# ____________________________________________________________________________________________________
# concatenate_87 (Concatenate)     (None, 112, 112, 144) 0           concatenate_86[0][0]
#                                                                    dropout_89[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_90 (BatchNor (None, 112, 112, 144) 576         concatenate_87[0][0]
# ____________________________________________________________________________________________________
# activation_90 (Activation)       (None, 112, 112, 144) 0           batch_normalization_90[0][0]
# ____________________________________________________________________________________________________
# conv2d_94 (Conv2D)               (None, 56, 56, 144)   20880       activation_90[0][0]
# ____________________________________________________________________________________________________
# dropout_90 (Dropout)             (None, 56, 56, 144)   0           conv2d_94[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_91 (BatchNor (None, 56, 56, 144)   576         dropout_90[0][0]
# ____________________________________________________________________________________________________
# activation_91 (Activation)       (None, 56, 56, 144)   0           batch_normalization_91[0][0]
# ____________________________________________________________________________________________________
# conv2d_95 (Conv2D)               (None, 56, 56, 12)    15564       activation_91[0][0]
# ____________________________________________________________________________________________________
# dropout_91 (Dropout)             (None, 56, 56, 12)    0           conv2d_95[0][0]
# ____________________________________________________________________________________________________
# concatenate_88 (Concatenate)     (None, 56, 56, 156)   0           dropout_90[0][0]
#                                                                    dropout_91[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_92 (BatchNor (None, 56, 56, 156)   624         concatenate_88[0][0]
# ____________________________________________________________________________________________________
# activation_92 (Activation)       (None, 56, 56, 156)   0           batch_normalization_92[0][0]
# ____________________________________________________________________________________________________
# conv2d_96 (Conv2D)               (None, 56, 56, 12)    16860       activation_92[0][0]
# ____________________________________________________________________________________________________
# dropout_92 (Dropout)             (None, 56, 56, 12)    0           conv2d_96[0][0]
# ____________________________________________________________________________________________________
# concatenate_89 (Concatenate)     (None, 56, 56, 168)   0           concatenate_88[0][0]
#                                                                    dropout_92[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_93 (BatchNor (None, 56, 56, 168)   672         concatenate_89[0][0]
# ____________________________________________________________________________________________________
# activation_93 (Activation)       (None, 56, 56, 168)   0           batch_normalization_93[0][0]
# ____________________________________________________________________________________________________
# conv2d_97 (Conv2D)               (None, 56, 56, 12)    18156       activation_93[0][0]
# ____________________________________________________________________________________________________
# dropout_93 (Dropout)             (None, 56, 56, 12)    0           conv2d_97[0][0]
# ____________________________________________________________________________________________________
# concatenate_90 (Concatenate)     (None, 56, 56, 180)   0           concatenate_89[0][0]
#                                                                    dropout_93[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_94 (BatchNor (None, 56, 56, 180)   720         concatenate_90[0][0]
# ____________________________________________________________________________________________________
# activation_94 (Activation)       (None, 56, 56, 180)   0           batch_normalization_94[0][0]
# ____________________________________________________________________________________________________
# conv2d_98 (Conv2D)               (None, 56, 56, 12)    19452       activation_94[0][0]
# ____________________________________________________________________________________________________
# dropout_94 (Dropout)             (None, 56, 56, 12)    0           conv2d_98[0][0]
# ____________________________________________________________________________________________________
# concatenate_91 (Concatenate)     (None, 56, 56, 192)   0           concatenate_90[0][0]
#                                                                    dropout_94[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_95 (BatchNor (None, 56, 56, 192)   768         concatenate_91[0][0]
# ____________________________________________________________________________________________________
# activation_95 (Activation)       (None, 56, 56, 192)   0           batch_normalization_95[0][0]
# ____________________________________________________________________________________________________
# conv2d_99 (Conv2D)               (None, 28, 28, 192)   37056       activation_95[0][0]
# ____________________________________________________________________________________________________
# dropout_95 (Dropout)             (None, 28, 28, 192)   0           conv2d_99[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_96 (BatchNor (None, 28, 28, 192)   768         dropout_95[0][0]
# ____________________________________________________________________________________________________
# activation_96 (Activation)       (None, 28, 28, 192)   0           batch_normalization_96[0][0]
# ____________________________________________________________________________________________________
# conv2d_100 (Conv2D)              (None, 28, 28, 12)    20748       activation_96[0][0]
# ____________________________________________________________________________________________________
# dropout_96 (Dropout)             (None, 28, 28, 12)    0           conv2d_100[0][0]
# ____________________________________________________________________________________________________
# concatenate_92 (Concatenate)     (None, 28, 28, 204)   0           dropout_95[0][0]
#                                                                    dropout_96[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_97 (BatchNor (None, 28, 28, 204)   816         concatenate_92[0][0]
# ____________________________________________________________________________________________________
# activation_97 (Activation)       (None, 28, 28, 204)   0           batch_normalization_97[0][0]
# ____________________________________________________________________________________________________
# conv2d_101 (Conv2D)              (None, 28, 28, 12)    22044       activation_97[0][0]
# ____________________________________________________________________________________________________
# dropout_97 (Dropout)             (None, 28, 28, 12)    0           conv2d_101[0][0]
# ____________________________________________________________________________________________________
# concatenate_93 (Concatenate)     (None, 28, 28, 216)   0           concatenate_92[0][0]
#                                                                    dropout_97[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_98 (BatchNor (None, 28, 28, 216)   864         concatenate_93[0][0]
# ____________________________________________________________________________________________________
# activation_98 (Activation)       (None, 28, 28, 216)   0           batch_normalization_98[0][0]
# ____________________________________________________________________________________________________
# conv2d_102 (Conv2D)              (None, 28, 28, 12)    23340       activation_98[0][0]
# ____________________________________________________________________________________________________
# dropout_98 (Dropout)             (None, 28, 28, 12)    0           conv2d_102[0][0]
# ____________________________________________________________________________________________________
# concatenate_94 (Concatenate)     (None, 28, 28, 228)   0           concatenate_93[0][0]
#                                                                    dropout_98[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_99 (BatchNor (None, 28, 28, 228)   912         concatenate_94[0][0]
# ____________________________________________________________________________________________________
# activation_99 (Activation)       (None, 28, 28, 228)   0           batch_normalization_99[0][0]
# ____________________________________________________________________________________________________
# conv2d_103 (Conv2D)              (None, 28, 28, 12)    24636       activation_99[0][0]
# ____________________________________________________________________________________________________
# dropout_99 (Dropout)             (None, 28, 28, 12)    0           conv2d_103[0][0]
# ____________________________________________________________________________________________________
# concatenate_95 (Concatenate)     (None, 28, 28, 240)   0           concatenate_94[0][0]
#                                                                    dropout_99[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_100 (BatchNo (None, 28, 28, 240)   960         concatenate_95[0][0]
# ____________________________________________________________________________________________________
# activation_100 (Activation)      (None, 28, 28, 240)   0           batch_normalization_100[0][0]
# ____________________________________________________________________________________________________
# conv2d_104 (Conv2D)              (None, 14, 14, 240)   57840       activation_100[0][0]
# ____________________________________________________________________________________________________
# dropout_100 (Dropout)            (None, 14, 14, 240)   0           conv2d_104[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_101 (BatchNo (None, 14, 14, 240)   960         dropout_100[0][0]
# ____________________________________________________________________________________________________
# activation_101 (Activation)      (None, 14, 14, 240)   0           batch_normalization_101[0][0]
# ____________________________________________________________________________________________________
# conv2d_105 (Conv2D)              (None, 14, 14, 12)    25932       activation_101[0][0]
# ____________________________________________________________________________________________________
# dropout_101 (Dropout)            (None, 14, 14, 12)    0           conv2d_105[0][0]
# ____________________________________________________________________________________________________
# concatenate_96 (Concatenate)     (None, 14, 14, 252)   0           dropout_100[0][0]
#                                                                    dropout_101[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_102 (BatchNo (None, 14, 14, 252)   1008        concatenate_96[0][0]
# ____________________________________________________________________________________________________
# activation_102 (Activation)      (None, 14, 14, 252)   0           batch_normalization_102[0][0]
# ____________________________________________________________________________________________________
# conv2d_106 (Conv2D)              (None, 14, 14, 12)    27228       activation_102[0][0]
# ____________________________________________________________________________________________________
# dropout_102 (Dropout)            (None, 14, 14, 12)    0           conv2d_106[0][0]
# ____________________________________________________________________________________________________
# concatenate_97 (Concatenate)     (None, 14, 14, 264)   0           concatenate_96[0][0]
#                                                                    dropout_102[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_103 (BatchNo (None, 14, 14, 264)   1056        concatenate_97[0][0]
# ____________________________________________________________________________________________________
# activation_103 (Activation)      (None, 14, 14, 264)   0           batch_normalization_103[0][0]
# ____________________________________________________________________________________________________
# conv2d_107 (Conv2D)              (None, 14, 14, 12)    28524       activation_103[0][0]
# ____________________________________________________________________________________________________
# dropout_103 (Dropout)            (None, 14, 14, 12)    0           conv2d_107[0][0]
# ____________________________________________________________________________________________________
# concatenate_98 (Concatenate)     (None, 14, 14, 276)   0           concatenate_97[0][0]
#                                                                    dropout_103[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_104 (BatchNo (None, 14, 14, 276)   1104        concatenate_98[0][0]
# ____________________________________________________________________________________________________
# activation_104 (Activation)      (None, 14, 14, 276)   0           batch_normalization_104[0][0]
# ____________________________________________________________________________________________________
# conv2d_108 (Conv2D)              (None, 14, 14, 12)    29820       activation_104[0][0]
# ____________________________________________________________________________________________________
# dropout_104 (Dropout)            (None, 14, 14, 12)    0           conv2d_108[0][0]
# ____________________________________________________________________________________________________
# concatenate_99 (Concatenate)     (None, 14, 14, 288)   0           concatenate_98[0][0]
#                                                                    dropout_104[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_105 (BatchNo (None, 14, 14, 288)   1152        concatenate_99[0][0]
# ____________________________________________________________________________________________________
# activation_105 (Activation)      (None, 14, 14, 288)   0           batch_normalization_105[0][0]
# ____________________________________________________________________________________________________
# conv2d_109 (Conv2D)              (None, 7, 7, 288)     83232       activation_105[0][0]
# ____________________________________________________________________________________________________
# dropout_105 (Dropout)            (None, 7, 7, 288)     0           conv2d_109[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_106 (BatchNo (None, 7, 7, 288)     1152        dropout_105[0][0]
# ____________________________________________________________________________________________________
# activation_106 (Activation)      (None, 7, 7, 288)     0           batch_normalization_106[0][0]
# ____________________________________________________________________________________________________
# conv2d_110 (Conv2D)              (None, 7, 7, 12)      31116       activation_106[0][0]
# ____________________________________________________________________________________________________
# dropout_106 (Dropout)            (None, 7, 7, 12)      0           conv2d_110[0][0]
# ____________________________________________________________________________________________________
# concatenate_100 (Concatenate)    (None, 7, 7, 300)     0           dropout_105[0][0]
#                                                                    dropout_106[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_107 (BatchNo (None, 7, 7, 300)     1200        concatenate_100[0][0]
# ____________________________________________________________________________________________________
# activation_107 (Activation)      (None, 7, 7, 300)     0           batch_normalization_107[0][0]
# ____________________________________________________________________________________________________
# conv2d_111 (Conv2D)              (None, 7, 7, 12)      32412       activation_107[0][0]
# ____________________________________________________________________________________________________
# dropout_107 (Dropout)            (None, 7, 7, 12)      0           conv2d_111[0][0]
# ____________________________________________________________________________________________________
# concatenate_101 (Concatenate)    (None, 7, 7, 312)     0           concatenate_100[0][0]
#                                                                    dropout_107[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_108 (BatchNo (None, 7, 7, 312)     1248        concatenate_101[0][0]
# ____________________________________________________________________________________________________
# activation_108 (Activation)      (None, 7, 7, 312)     0           batch_normalization_108[0][0]
# ____________________________________________________________________________________________________
# conv2d_112 (Conv2D)              (None, 7, 7, 12)      33708       activation_108[0][0]
# ____________________________________________________________________________________________________
# dropout_108 (Dropout)            (None, 7, 7, 12)      0           conv2d_112[0][0]
# ____________________________________________________________________________________________________
# concatenate_102 (Concatenate)    (None, 7, 7, 324)     0           concatenate_101[0][0]
#                                                                    dropout_108[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_109 (BatchNo (None, 7, 7, 324)     1296        concatenate_102[0][0]
# ____________________________________________________________________________________________________
# activation_109 (Activation)      (None, 7, 7, 324)     0           batch_normalization_109[0][0]
# ____________________________________________________________________________________________________
# conv2d_113 (Conv2D)              (None, 7, 7, 12)      35004       activation_109[0][0]
# ____________________________________________________________________________________________________
# dropout_109 (Dropout)            (None, 7, 7, 12)      0           conv2d_113[0][0]
# ____________________________________________________________________________________________________
# concatenate_104 (Concatenate)    (None, 7, 7, 48)      0           dropout_106[0][0]
#                                                                    dropout_107[0][0]
#                                                                    dropout_108[0][0]
#                                                                    dropout_109[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTransp (None, 14, 14, 48)    20784       concatenate_104[0][0]
# ____________________________________________________________________________________________________
# concatenate_105 (Concatenate)    (None, 14, 14, 336)   0           conv2d_transpose_6[0][0]
#                                                                    concatenate_99[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_111 (BatchNo (None, 14, 14, 336)   1344        concatenate_105[0][0]
# ____________________________________________________________________________________________________
# activation_111 (Activation)      (None, 14, 14, 336)   0           batch_normalization_111[0][0]
# ____________________________________________________________________________________________________
# conv2d_115 (Conv2D)              (None, 14, 14, 12)    36300       activation_111[0][0]
# ____________________________________________________________________________________________________
# dropout_111 (Dropout)            (None, 14, 14, 12)    0           conv2d_115[0][0]
# ____________________________________________________________________________________________________
# concatenate_106 (Concatenate)    (None, 14, 14, 348)   0           concatenate_105[0][0]
#                                                                    dropout_111[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_112 (BatchNo (None, 14, 14, 348)   1392        concatenate_106[0][0]
# ____________________________________________________________________________________________________
# activation_112 (Activation)      (None, 14, 14, 348)   0           batch_normalization_112[0][0]
# ____________________________________________________________________________________________________
# conv2d_116 (Conv2D)              (None, 14, 14, 12)    37596       activation_112[0][0]
# ____________________________________________________________________________________________________
# dropout_112 (Dropout)            (None, 14, 14, 12)    0           conv2d_116[0][0]
# ____________________________________________________________________________________________________
# concatenate_107 (Concatenate)    (None, 14, 14, 360)   0           concatenate_106[0][0]
#                                                                    dropout_112[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_113 (BatchNo (None, 14, 14, 360)   1440        concatenate_107[0][0]
# ____________________________________________________________________________________________________
# activation_113 (Activation)      (None, 14, 14, 360)   0           batch_normalization_113[0][0]
# ____________________________________________________________________________________________________
# conv2d_117 (Conv2D)              (None, 14, 14, 12)    38892       activation_113[0][0]
# ____________________________________________________________________________________________________
# dropout_113 (Dropout)            (None, 14, 14, 12)    0           conv2d_117[0][0]
# ____________________________________________________________________________________________________
# concatenate_108 (Concatenate)    (None, 14, 14, 372)   0           concatenate_107[0][0]
#                                                                    dropout_113[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_114 (BatchNo (None, 14, 14, 372)   1488        concatenate_108[0][0]
# ____________________________________________________________________________________________________
# activation_114 (Activation)      (None, 14, 14, 372)   0           batch_normalization_114[0][0]
# ____________________________________________________________________________________________________
# conv2d_118 (Conv2D)              (None, 14, 14, 12)    40188       activation_114[0][0]
# ____________________________________________________________________________________________________
# dropout_114 (Dropout)            (None, 14, 14, 12)    0           conv2d_118[0][0]
# ____________________________________________________________________________________________________
# concatenate_110 (Concatenate)    (None, 14, 14, 48)    0           dropout_111[0][0]
#                                                                    dropout_112[0][0]
#                                                                    dropout_113[0][0]
#                                                                    dropout_114[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTransp (None, 28, 28, 48)    20784       concatenate_110[0][0]
# ____________________________________________________________________________________________________
# concatenate_111 (Concatenate)    (None, 28, 28, 288)   0           conv2d_transpose_7[0][0]
#                                                                    concatenate_95[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_115 (BatchNo (None, 28, 28, 288)   1152        concatenate_111[0][0]
# ____________________________________________________________________________________________________
# activation_115 (Activation)      (None, 28, 28, 288)   0           batch_normalization_115[0][0]
# ____________________________________________________________________________________________________
# conv2d_119 (Conv2D)              (None, 28, 28, 12)    31116       activation_115[0][0]
# ____________________________________________________________________________________________________
# dropout_115 (Dropout)            (None, 28, 28, 12)    0           conv2d_119[0][0]
# ____________________________________________________________________________________________________
# concatenate_112 (Concatenate)    (None, 28, 28, 300)   0           concatenate_111[0][0]
#                                                                    dropout_115[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_116 (BatchNo (None, 28, 28, 300)   1200        concatenate_112[0][0]
# ____________________________________________________________________________________________________
# activation_116 (Activation)      (None, 28, 28, 300)   0           batch_normalization_116[0][0]
# ____________________________________________________________________________________________________
# conv2d_120 (Conv2D)              (None, 28, 28, 12)    32412       activation_116[0][0]
# ____________________________________________________________________________________________________
# dropout_116 (Dropout)            (None, 28, 28, 12)    0           conv2d_120[0][0]
# ____________________________________________________________________________________________________
# concatenate_113 (Concatenate)    (None, 28, 28, 312)   0           concatenate_112[0][0]
#                                                                    dropout_116[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_117 (BatchNo (None, 28, 28, 312)   1248        concatenate_113[0][0]
# ____________________________________________________________________________________________________
# activation_117 (Activation)      (None, 28, 28, 312)   0           batch_normalization_117[0][0]
# ____________________________________________________________________________________________________
# conv2d_121 (Conv2D)              (None, 28, 28, 12)    33708       activation_117[0][0]
# ____________________________________________________________________________________________________
# dropout_117 (Dropout)            (None, 28, 28, 12)    0           conv2d_121[0][0]
# ____________________________________________________________________________________________________
# concatenate_114 (Concatenate)    (None, 28, 28, 324)   0           concatenate_113[0][0]
#                                                                    dropout_117[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_118 (BatchNo (None, 28, 28, 324)   1296        concatenate_114[0][0]
# ____________________________________________________________________________________________________
# activation_118 (Activation)      (None, 28, 28, 324)   0           batch_normalization_118[0][0]
# ____________________________________________________________________________________________________
# conv2d_122 (Conv2D)              (None, 28, 28, 12)    35004       activation_118[0][0]
# ____________________________________________________________________________________________________
# dropout_118 (Dropout)            (None, 28, 28, 12)    0           conv2d_122[0][0]
# ____________________________________________________________________________________________________
# concatenate_116 (Concatenate)    (None, 28, 28, 48)    0           dropout_115[0][0]
#                                                                    dropout_116[0][0]
#                                                                    dropout_117[0][0]
#                                                                    dropout_118[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTransp (None, 56, 56, 48)    20784       concatenate_116[0][0]
# ____________________________________________________________________________________________________
# concatenate_117 (Concatenate)    (None, 56, 56, 240)   0           conv2d_transpose_8[0][0]
#                                                                    concatenate_91[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_119 (BatchNo (None, 56, 56, 240)   960         concatenate_117[0][0]
# ____________________________________________________________________________________________________
# activation_119 (Activation)      (None, 56, 56, 240)   0           batch_normalization_119[0][0]
# ____________________________________________________________________________________________________
# conv2d_123 (Conv2D)              (None, 56, 56, 12)    25932       activation_119[0][0]
# ____________________________________________________________________________________________________
# dropout_119 (Dropout)            (None, 56, 56, 12)    0           conv2d_123[0][0]
# ____________________________________________________________________________________________________
# concatenate_118 (Concatenate)    (None, 56, 56, 252)   0           concatenate_117[0][0]
#                                                                    dropout_119[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_120 (BatchNo (None, 56, 56, 252)   1008        concatenate_118[0][0]
# ____________________________________________________________________________________________________
# activation_120 (Activation)      (None, 56, 56, 252)   0           batch_normalization_120[0][0]
# ____________________________________________________________________________________________________
# conv2d_124 (Conv2D)              (None, 56, 56, 12)    27228       activation_120[0][0]
# ____________________________________________________________________________________________________
# dropout_120 (Dropout)            (None, 56, 56, 12)    0           conv2d_124[0][0]
# ____________________________________________________________________________________________________
# concatenate_119 (Concatenate)    (None, 56, 56, 264)   0           concatenate_118[0][0]
#                                                                    dropout_120[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_121 (BatchNo (None, 56, 56, 264)   1056        concatenate_119[0][0]
# ____________________________________________________________________________________________________
# activation_121 (Activation)      (None, 56, 56, 264)   0           batch_normalization_121[0][0]
# ____________________________________________________________________________________________________
# conv2d_125 (Conv2D)              (None, 56, 56, 12)    28524       activation_121[0][0]
# ____________________________________________________________________________________________________
# dropout_121 (Dropout)            (None, 56, 56, 12)    0           conv2d_125[0][0]
# ____________________________________________________________________________________________________
# concatenate_120 (Concatenate)    (None, 56, 56, 276)   0           concatenate_119[0][0]
#                                                                    dropout_121[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_122 (BatchNo (None, 56, 56, 276)   1104        concatenate_120[0][0]
# ____________________________________________________________________________________________________
# activation_122 (Activation)      (None, 56, 56, 276)   0           batch_normalization_122[0][0]
# ____________________________________________________________________________________________________
# conv2d_126 (Conv2D)              (None, 56, 56, 12)    29820       activation_122[0][0]
# ____________________________________________________________________________________________________
# dropout_122 (Dropout)            (None, 56, 56, 12)    0           conv2d_126[0][0]
# ____________________________________________________________________________________________________
# concatenate_122 (Concatenate)    (None, 56, 56, 48)    0           dropout_119[0][0]
#                                                                    dropout_120[0][0]
#                                                                    dropout_121[0][0]
#                                                                    dropout_122[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTransp (None, 112, 112, 48)  20784       concatenate_122[0][0]
# ____________________________________________________________________________________________________
# concatenate_123 (Concatenate)    (None, 112, 112, 192) 0           conv2d_transpose_9[0][0]
#                                                                    concatenate_87[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_123 (BatchNo (None, 112, 112, 192) 768         concatenate_123[0][0]
# ____________________________________________________________________________________________________
# activation_123 (Activation)      (None, 112, 112, 192) 0           batch_normalization_123[0][0]
# ____________________________________________________________________________________________________
# conv2d_127 (Conv2D)              (None, 112, 112, 12)  20748       activation_123[0][0]
# ____________________________________________________________________________________________________
# dropout_123 (Dropout)            (None, 112, 112, 12)  0           conv2d_127[0][0]
# ____________________________________________________________________________________________________
# concatenate_124 (Concatenate)    (None, 112, 112, 204) 0           concatenate_123[0][0]
#                                                                    dropout_123[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_124 (BatchNo (None, 112, 112, 204) 816         concatenate_124[0][0]
# ____________________________________________________________________________________________________
# activation_124 (Activation)      (None, 112, 112, 204) 0           batch_normalization_124[0][0]
# ____________________________________________________________________________________________________
# conv2d_128 (Conv2D)              (None, 112, 112, 12)  22044       activation_124[0][0]
# ____________________________________________________________________________________________________
# dropout_124 (Dropout)            (None, 112, 112, 12)  0           conv2d_128[0][0]
# ____________________________________________________________________________________________________
# concatenate_125 (Concatenate)    (None, 112, 112, 216) 0           concatenate_124[0][0]
#                                                                    dropout_124[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_125 (BatchNo (None, 112, 112, 216) 864         concatenate_125[0][0]
# ____________________________________________________________________________________________________
# activation_125 (Activation)      (None, 112, 112, 216) 0           batch_normalization_125[0][0]
# ____________________________________________________________________________________________________
# conv2d_129 (Conv2D)              (None, 112, 112, 12)  23340       activation_125[0][0]
# ____________________________________________________________________________________________________
# dropout_125 (Dropout)            (None, 112, 112, 12)  0           conv2d_129[0][0]
# ____________________________________________________________________________________________________
# concatenate_126 (Concatenate)    (None, 112, 112, 228) 0           concatenate_125[0][0]
#                                                                    dropout_125[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_126 (BatchNo (None, 112, 112, 228) 912         concatenate_126[0][0]
# ____________________________________________________________________________________________________
# activation_126 (Activation)      (None, 112, 112, 228) 0           batch_normalization_126[0][0]
# ____________________________________________________________________________________________________
# conv2d_130 (Conv2D)              (None, 112, 112, 12)  24636       activation_126[0][0]
# ____________________________________________________________________________________________________
# dropout_126 (Dropout)            (None, 112, 112, 12)  0           conv2d_130[0][0]
# ____________________________________________________________________________________________________
# concatenate_128 (Concatenate)    (None, 112, 112, 48)  0           dropout_123[0][0]
#                                                                    dropout_124[0][0]
#                                                                    dropout_125[0][0]
#                                                                    dropout_126[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTrans (None, 224, 224, 48)  20784       concatenate_128[0][0]
# ____________________________________________________________________________________________________
# concatenate_129 (Concatenate)    (None, 224, 224, 144) 0           conv2d_transpose_10[0][0]
#                                                                    concatenate_83[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_127 (BatchNo (None, 224, 224, 144) 576         concatenate_129[0][0]
# ____________________________________________________________________________________________________
# activation_127 (Activation)      (None, 224, 224, 144) 0           batch_normalization_127[0][0]
# ____________________________________________________________________________________________________
# conv2d_131 (Conv2D)              (None, 224, 224, 12)  15564       activation_127[0][0]
# ____________________________________________________________________________________________________
# dropout_127 (Dropout)            (None, 224, 224, 12)  0           conv2d_131[0][0]
# ____________________________________________________________________________________________________
# concatenate_130 (Concatenate)    (None, 224, 224, 156) 0           concatenate_129[0][0]
#                                                                    dropout_127[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_128 (BatchNo (None, 224, 224, 156) 624         concatenate_130[0][0]
# ____________________________________________________________________________________________________
# activation_128 (Activation)      (None, 224, 224, 156) 0           batch_normalization_128[0][0]
# ____________________________________________________________________________________________________
# conv2d_132 (Conv2D)              (None, 224, 224, 12)  16860       activation_128[0][0]
# ____________________________________________________________________________________________________
# dropout_128 (Dropout)            (None, 224, 224, 12)  0           conv2d_132[0][0]
# ____________________________________________________________________________________________________
# concatenate_131 (Concatenate)    (None, 224, 224, 168) 0           concatenate_130[0][0]
#                                                                    dropout_128[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_129 (BatchNo (None, 224, 224, 168) 672         concatenate_131[0][0]
# ____________________________________________________________________________________________________
# activation_129 (Activation)      (None, 224, 224, 168) 0           batch_normalization_129[0][0]
# ____________________________________________________________________________________________________
# conv2d_133 (Conv2D)              (None, 224, 224, 12)  18156       activation_129[0][0]
# ____________________________________________________________________________________________________
# dropout_129 (Dropout)            (None, 224, 224, 12)  0           conv2d_133[0][0]
# ____________________________________________________________________________________________________
# concatenate_132 (Concatenate)    (None, 224, 224, 180) 0           concatenate_131[0][0]
#                                                                    dropout_129[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_130 (BatchNo (None, 224, 224, 180) 720         concatenate_132[0][0]
# ____________________________________________________________________________________________________
# activation_130 (Activation)      (None, 224, 224, 180) 0           batch_normalization_130[0][0]
# ____________________________________________________________________________________________________
# conv2d_134 (Conv2D)              (None, 224, 224, 12)  19452       activation_130[0][0]
# ____________________________________________________________________________________________________
# dropout_130 (Dropout)            (None, 224, 224, 12)  0           conv2d_134[0][0]
# ____________________________________________________________________________________________________
# concatenate_133 (Concatenate)    (None, 224, 224, 192) 0           concatenate_132[0][0]
#                                                                    dropout_130[0][0]
# ____________________________________________________________________________________________________
# conv2d_135 (Conv2D)              (None, 224, 224, 33)  6369        concatenate_133[0][0]
# ____________________________________________________________________________________________________
# reshape_1 (Reshape)              (None, 50176, 33)     0           conv2d_135[0][0]
# ____________________________________________________________________________________________________
# activation_131 (Activation)      (None, 50176, 33)     0           reshape_1[0][0]
# ====================================================================================================
# Total params: 1,402,209
# Trainable params: 1,381,041
# Non-trainable params: 21,168
# ____________________________________________________________________________________________________

# %% [markdown]
# ## 5. View results

# %% [markdown]
# ### 5.1 Import RGB data and names for each class

# %%
colors = [(64, 128, 64), (192, 0, 128), (0, 128, 192),(0, 128, 64), (128, 0, 0), (64, 0, 128), (64, 0, 192), (192, 128, 64), (192, 192, 128), (64, 64, 128),
 (128, 0, 192), (192, 0, 64), (128, 128, 64), (192, 0, 192), (128, 64, 64), (64, 192, 128), (64, 64, 0), (128, 64, 128), (128, 128, 192), (0, 0, 192),
(192, 128, 128), (128, 128, 128), (64, 128, 192), (0, 0, 64),(0 ,64, 64), (192, 64, 128), (128, 128, 0), (192, 128, 192), (64, 0, 64),(192, 192, 0),
 (0, 0, 0), (64, 192, 0)]

names = ['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car','CartLuggagePram', 'Child', 'Column_Pole','Fence', 'LaneMkgsDriv', 
         'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving','ParkingBlock','Pedestrian','Road', 'RoadShoulder','RoadShoulder',
         'Sidewalk', 'SignSymbol','Sky', 'SUVPickupTruck','TrafficCone', 'TrafficLight','Train','Tree','Truck_Bus', 'Tunnel','VegetationMisc','Void',
         'Wall']

# %%
# Import the model created above
from keras.models import load_model
model = load_model('tiramisu.11-0.86.hdf5')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 5.2 view the result of exmaples

# %%
i=3

# %%
b = np.expand_dims(b_img[i], axis=0)
print(np.shape(b))

p = model.predict(b)
print(np.shape(p))

p = np.argmax(p[0],-1).reshape(224,224)
print(np.shape(p))
# Out:
# (1, 224, 224, 3)
# (1, 50176, 33)
# (224, 224)

# %%
def color_label(i): 
    res = np.zeros((r,c,3), 'uint8')
    for j in range(r): 
        for k in range(c):
            res[j,k,:] = colors[p[j,k]]
    return res

# %%
r=224
c=224
pred = color_label(p)

# %%
# Show the sample images
bl=b_label[i].reshape(224,224,3)

imm=[(b_img[i]*0.3+0.4), bl, pred]
title=['original','ground-truth','prediction']
plt.figure(figsize=(20,15))

for i in range(len(imm)):
    plt.subplot(1,3, i+1)
    plt.imshow(imm[i]) 
    plt.title(title[i],fontsize=30)

# %% [markdown]
# Notice: TOSHI STATS SDN. BHD. and I do not accept any responsibility or liability for loss or damage occasioned to any person or property through using materials, instructions, methods, algorithm or ideas contained herein, or acting or refraining from acting as a result of such use. TOSHI STATS SDN. BHD. and I expressly disclaim all implied warranties, including merchantability or fitness for any particular purpose. There will be no duty on TOSHI STATS SDN. BHD. and me to correct any errors or defects in the codes and the software
